# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
        
    return arr

# %%
def test():
    data = [64, 25, 12, 22, 11]
    print(f"排序前的数据: {data}")
    sorted_data = selection_sort(data)
    print(f"排序后的结果: {sorted_data}")
    assert sorted_data == [11, 12, 22, 25, 64], "排序结果错误！"
    print("验证通过！")

# %%
test()
# Out:
# 排序前的数据: [64, 25, 12, 22, 11]
# 排序后的结果: [11, 12, 22, 25, 64]
# 验证通过！

# %%
def test_interactive():
    user_input = input("请输入一组数字（用空格分隔，例如：5 2 9 1）：")
    
    try:
        data = [int(x) for x in user_input.split()]
        print(f"你输入的数据: {data}")
        result = selection_sort(data)
        print(f"排序后的结果: {result}")
    except ValueError:
        print("错误：请输入有效的整数数字！")

test_interactive()
# Out:
# 请输入一组数字（用空格分隔，例如：5 2 9 1）： 19 98 46 36
# 你输入的数据: [19, 98, 46, 36]
# 排序后的结果: [19, 36, 46, 98]
